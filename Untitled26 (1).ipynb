# %%
class player:

    def __init__(self, name):
        self.name = name

    def warrior(self):
        self.hp_warrior = 150
        self.attack_warrior = 30
        self.defence_warrior = 25
        self.weapon_warrior = "Sword"
        self.potion_warrior = 3
        self.coin_warrior = 0

    def mage(self):
        self.hp_mage = 90
        self.attack_mage = 45
        self.defence_mage = 15
        self.weapon_mage = "Magical Staff"
        self.potion_mage = 4
        self.coin_mage = 0

    def assassin(self):
        self.hp_assassin = 110
        self.attack_assassin = 40
        self.defence_assassin = 18
        self.weapon_assassin = "Dagger"
        self.potion_assassin = 3
        self.coin_assassin = 0

    def choice(self):
        ans = int(input("Enter your choice : "))

        if ans == 1:
            self.choice_name = "Warrior"
            self.warrior()
            print("\nYou choosed Warrior")
            print("HP :", self.hp_warrior)
            print("Attack :", self.attack_warrior)
            print("Defence :", self.defence_warrior)
            print("Weapon :", self.weapon_warrior)
            print("Potion :", self.potion_warrior)
            print("Coins :", self.coin_warrior)

        elif ans == 2:
            self.choice_name = "Mage"
            self.mage()
            print("\nYou choosed Mage")
            print("HP :", self.hp_mage)
            print("Attack :", self.attack_mage)
            print("Defence :", self.defence_mage)
            print("Weapon :", self.weapon_mage)
            print("Potion :", self.potion_mage)
            print("Coins :", self.coin_mage)

        elif ans == 3:
            self.choice_name = "Assassin"
            self.assassin()
            print("\nYou choosed Assassin")
            print("HP :", self.hp_assassin)
            print("Attack :", self.attack_assassin)
            print("Defence :", self.defence_assassin)
            print("Weapon :", self.weapon_assassin)
            print("Potion :", self.potion_assassin)
            print("Coins :", self.coin_assassin)

        else:
            print("Invalid choice")

    def golbin(self):
        self.hp_golbin = 70
        self.attack_golbin = 18
        self.defence_golbin = 10
        self.weapon_golbin = "Club"
        self.potion_golbin = 1
        self.coin_golbin = 15

    def skeleton(self):
        self.hp_skeleton = 90
        self.attack_skeleton = 22
        self.defence_skeleton = 12
        self.weapon_skeleton = "Bone Sword"
        self.potion_skeleton = 1
        self.coin_skeleton = 20

    def orc(self):
        self.hp_orc = 130
        self.attack_orc = 28
        self.defence_orc = 18
        self.weapon_orc = "Axe"
        self.potion_orc = 2
        self.coin_orc = 30

    def dragon(self):
        self.hp_dragon = 300
        self.attack_dragon = 45
        self.defence_dragon = 36
        self.weapon_dragon = "Fire Breath"
        self.potion_dragon = 3
        self.coin_dragon = 100

    def enemy(self):
        import random as ran

        ans = ran.randint(1, 4)

        if ans == 1:
            self.enemy_name = "Golbin"
            self.golbin()

        elif ans == 2:
            self.enemy_name = "Skeleton"
            self.skeleton()

        elif ans == 3:
            self.enemy_name = "Orc"
            self.orc()

        elif ans == 4:
            self.enemy_name = "Dragon"
            self.dragon()

        print("\nEnemy :", self.enemy_name)

    def attack(self):

        if self.choice_name == "Warrior":

            if self.enemy_name == "Golbin":
                damage_golbin = int((self.attack_warrior * 100) / (100 + self.defence_golbin))
                self.hp_golbin = self.hp_golbin - damage_golbin
                print(f"Damage : {damage_golbin}")
                print(f"{self.enemy_name} HP : {self.hp_golbin}")

            elif self.enemy_name == "Skeleton":
                damage_skeleton = int((self.attack_warrior * 100) / (100 + self.defence_skeleton))
                self.hp_skeleton = self.hp_skeleton - damage_skeleton
                print(f"Damage : {damage_skeleton}")
                print(f"{self.enemy_name} HP : {self.hp_skeleton}")

            elif self.enemy_name == "Orc":
                damage_orc = int((self.attack_warrior * 100) / (100 + self.defence_orc))
                self.hp_orc = self.hp_orc - damage_orc
                print(f"Damage : {damage_orc}")
                print(f"{self.enemy_name} HP : {self.hp_orc}")

            elif self.enemy_name == "Dragon":
                damage_dragon = int((self.attack_warrior * 100) / (100 + self.defence_dragon))
                self.hp_dragon = self.hp_dragon - damage_dragon
                print(f"Damage : {damage_dragon}")
                print(f"{self.enemy_name} HP : {self.hp_dragon}")

        elif self.choice_name == "Mage":

            if self.enemy_name == "Golbin":
                damage_golbin = int((self.attack_mage * 100) / (100 + self.defence_golbin))
                self.hp_golbin = self.hp_golbin - damage_golbin
                print(f"Damage : {damage_golbin}")
                print(f"{self.enemy_name} HP : {self.hp_golbin}")

            elif self.enemy_name == "Skeleton":
                damage_skeleton = int((self.attack_mage * 100) / (100 + self.defence_skeleton))
                self.hp_skeleton = self.hp_skeleton - damage_skeleton
                print(f"Damage : {damage_skeleton}")
                print(f"{self.enemy_name} HP : {self.hp_skeleton}")

            elif self.enemy_name == "Orc":
                damage_orc = int((self.attack_mage * 100) / (100 + self.defence_orc))
                self.hp_orc = self.hp_orc - damage_orc
                print(f"Damage : {damage_orc}")
                print(f"{self.enemy_name} HP : {self.hp_orc}")

            elif self.enemy_name == "Dragon":
                damage_dragon = int((self.attack_mage * 100) / (100 + self.defence_dragon))
                self.hp_dragon = self.hp_dragon - damage_dragon
                print(f"Damage : {damage_dragon}")
                print(f"{self.enemy_name} HP : {self.hp_dragon}")

        elif self.choice_name == "Assassin":

            if self.enemy_name == "Golbin":
                damage_golbin = int((self.attack_assassin * 100) / (100 + self.defence_golbin))
                self.hp_golbin = self.hp_golbin - damage_golbin
                print(f"Damage : {damage_golbin}")
                print(f"{self.enemy_name} HP : {self.hp_golbin}")

            elif self.enemy_name == "Skeleton":
                damage_skeleton = int((self.attack_assassin * 100) / (100 + self.defence_skeleton))
                self.hp_skeleton = self.hp_skeleton - damage_skeleton
                print(f"Damage : {damage_skeleton}")
                print(f"{self.enemy_name} HP : {self.hp_skeleton}")

            elif self.enemy_name == "Orc":
                damage_orc = int((self.attack_assassin * 100) / (100 + self.defence_orc))
                self.hp_orc = self.hp_orc - damage_orc
                print(f"Damage : {damage_orc}")
                print(f"{self.enemy_name} HP : {self.hp_orc}")

            elif self.enemy_name == "Dragon":
                damage_dragon = int((self.attack_assassin * 100) / (100 + self.defence_dragon))
                self.hp_dragon = self.hp_dragon - damage_dragon
                print(f"Damage : {damage_dragon}")
                print(f"{self.enemy_name} HP : {self.hp_dragon}")

    def defend_player(self):

        if self.choice_name == "Warrior":
            self.defence_warrior += 10
            print("\nNew Defenc : ",self.defence_warrior)

        elif self.choice_name == "Mage":
            self.defence_mage += 10
            print("\nNew Defenc : ",self.defence_mage)

        elif self.choice_name == "Assassin":
            self.defence_assassin += 10
            print("\nNew Defenc : ",self.defence_warrior)
            
        return

    def potition_player(self):

        if self.choice_name == "Warrior":
            self.hp_warrior = self.hp_warrior + self.potion_warrior
            print("\nNew HP : ",self.hp_warrior)

        elif self.choice_name == "Mage":
            self.hp_mage = self.hp_mage + self.potion_mage
            print("\nNew HP : ",self.hp_mage)

        elif self.choice_name == "Assassin":
            self.hp_assassin = self.hp_assassin + self.potion_assassin
            print("\nNew HP : ",self.hp_assassin)

        return

    def option(self):

        print("""
Choose your action
1. Attack
2. Defend
3. Use Potion
4. Run
""")

        ans = int(input("Enter your choice : "))

        if ans == 1:
            print(f"{self.name} attacked {self.enemy_name}\n")
            self.attack()

        elif ans == 2:
            print("\n", self.choice_name, "Choosed defence")
            self.defend_player()

        elif ans == 3:
            print("\nYour choosed Potion")
            self.potition_player()

        elif ans == 4:
            print("\nYou ran away")
            print(f"\n{self.enemy_name} won!!!!")

        return True

    def attack_enemy(self):

        if self.enemy_name == "Golbin":

            if self.choice_name == "Warrior":
                damage_warrior = int((self.attack_golbin * 100) / (100 + self.defence_warrior))
                self.hp_warrior = self.hp_warrior - damage_warrior
                print(f"Damage recieved : {damage_warrior}")
                print(f"{self.name} HP : {self.hp_warrior}")

            elif self.choice_name == "Mage":
                damage_mage = int((self.attack_golbin * 100) / (100 + self.defence_mage))
                self.hp_mage = self.hp_mage - damage_mage
                print(f"Damage recieved : {damage_mage}")
                print(f"{self.name} HP : {self.hp_mage}")

            elif self.choice_name == "Assassin":
                damage_assassin = int((self.attack_golbin * 100) / (100 + self.defence_assassin))
                self.hp_assassin = self.hp_assassin - damage_assassin
                print(f"Damage recieved : {damage_assassin}")
                print(f"{self.name} HP : {self.hp_assassin}")

        elif self.enemy_name == "Skeleton":

            if self.choice_name == "Warrior":
                damage_warrior = int((self.attack_skeleton * 100) / (100 + self.defence_warrior))
                self.hp_warrior = self.hp_warrior - damage_warrior
                print(f"Damage recieved : {damage_warrior}")
                print(f"{self.name} HP : {self.hp_warrior}")

            elif self.choice_name == "Mage":
                damage_mage = int((self.attack_skeleton * 100) / (100 + self.defence_mage))
                self.hp_mage = self.hp_mage - damage_mage
                print(f"Damage recieved : {damage_mage}")
                print(f"{self.name} HP : {self.hp_mage}")

            elif self.choice_name == "Assassin":
                damage_assassin = int((self.attack_skeleton * 100) / (100 + self.defence_assassin))
                self.hp_assassin = self.hp_assassin - damage_assassin
                print(f"Damage recieved : {damage_assassin}")
                print(f"{self.name} HP : {self.hp_assassin}")

        elif self.enemy_name == "Orc":

            if self.choice_name == "Warrior":
                damage_warrior = int((self.attack_orc * 100) / (100 + self.defence_warrior))
                self.hp_warrior = self.hp_warrior - damage_warrior
                print(f"Damage recieved : {damage_warrior}")
                print(f"{self.name} HP : {self.hp_warrior}")

            elif self.choice_name == "Mage":
                damage_mage = int((self.attack_orc * 100) / (100 + self.defence_mage))
                self.hp_mage = self.hp_mage - damage_mage
                print(f"Damage recieved : {damage_mage}")
                print(f"{self.name} HP : {self.hp_mage}")

            elif self.choice_name == "Assassin":
                damage_assassin = int((self.attack_orc * 100) / (100 + self.defence_assassin))
                self.hp_assassin = self.hp_assassin - damage_assassin
                print(f"Damage recieved : {damage_assassin}")
                print(f"{self.name} HP : {self.hp_assassin}")

        elif self.enemy_name == "Dragon":

            if self.choice_name == "Warrior":
                damage_warrior = int((self.attack_dragon * 100) / (100 + self.defence_warrior))
                self.hp_warrior = self.hp_warrior - damage_warrior
                print(f"Damage recieved : {damage_warrior}")
                print(f"{self.name} HP : {self.hp_warrior}")

            elif self.choice_name == "Mage":
                damage_mage = int((self.attack_dragon * 100) / (100 + self.defence_mage))
                self.hp_mage = self.hp_mage - damage_mage
                print(f"Damage recieved : {damage_mage}")
                print(f"{self.name} HP : {self.hp_mage}")

            elif self.choice_name == "Assassin":
                damage_assassin = int((self.attack_dragon * 100) / (100 + self.defence_assassin))
                self.hp_assassin = self.hp_assassin - damage_assassin
                print(f"Damage recieved : {damage_assassin}")
                print(f"{self.name} HP : {self.hp_assassin}")

    def defend_enemy(self):

        if self.enemy_name == "Golbin":
            self.defence_golbin += 10
            print("\nNew Defenc : ",self.defence_golbin)

        elif self.enemy_name == "Skeleton":
            self.defence_skeleton += 10
            print("\nNew Defenc : ",self.defence_skeleton)

        elif self.enemy_name == "Orc":
            self.defence_orc += 10
            print("\nNew Defenc : ",self.defence_orc)

        elif self.enemy_name == "Dragon":
            self.defence_dragon += 10
            print("\nNew Defenc : ",self.defence_dragon)

        return

    def potition_enemy(self):

        if self.enemy_name == "Golbin":
            self.hp_golbin = self.hp_golbin + self.potion_golbin
            print("\nNew HP : ",self.hp_golbin)

        elif self.enemy_name == "Skeleton":
            self.hp_skeleton = self.hp_skeleton + self.potion_skeleton
            print("\nNew HP : ",self.hp_skeleton)

        elif self.enemy_name == "Orc":
            self.hp_orc = self.hp_orc + self.potion_orc
            print("\nNew HP : ",self.hp_orc)

        elif self.enemy_name == "Dragon":
            self.hp_dragon = self.hp_dragon + self.potion_dragon
            print("\nNew HP : ",self.hp_dragon)

        return

    def enemey_option(self):

        import random as ran

        ans = ran.randint(1, 4)

        if ans == 1:
            print(f"\n{self.enemy_name} attacked {self.name}")
            self.attack_enemy()

        elif ans == 2:
            print(f"\n{self.enemy_name} Defended itself")
            self.defend_enemy()

        elif ans == 3:
            print("\nEnemy choosed Potion\n")
            self.potition_enemy()

        elif ans == 4:
            print("\nEnemy ran away")
            print(f"\nYou won!!!!")


print("=====================\n\tWORLD\t\n=====================")

name = input("\nEnter your name: ")

play = player(name)

print("""
Choose your character
1. Warrior
2. Mage
3. Assassin
""")

play.choice()

print("\n==============================\n\tYour advanture begins\t\n=========================\n")

print("\nYou entered a Dark Forest.....\n\nAn Enemy appeared!")

play.enemy()

play.option()

play.enemey_option()
# Out:
# ...
# 	WORLD
# ...
# Enter your name:  Shivika
# Choose your character
# 1. Warrior
# 2. Mage
# 3. Assassin
# Enter your choice :  3
# You choosed Assassin
# HP : 110
# Attack : 40
# Defence : 18
# Weapon : Dagger
# Potion : 3
# Coins : 0
#
# ...
# 	Your advanture begins
# ...
#
#
# You entered a Dark Forest.....
#
# An Enemy appeared!
#
# Enemy : Orc
#
# Choose your action
# 1. Attack
# 2. Defend
# 3. Use Potion
# 4. Run
# Enter your choice :  4
# You ran away
#
# Orc won!!!!
#
# Orc attacked Shivika
# Damage recieved : 23
# Shivika HP : 87
